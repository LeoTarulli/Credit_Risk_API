# %% [markdown]
# # Credit Risk Project

# %% [markdown]
# Understanding our Dataset
#
# * checking_status: The currently balance account.
# * duration: duration of the credit payment, in months.
# * credit_history: Is the customer credit history. It can have the following values:
# * existing paid: currently credit process
# * all paid: all the credit abre paid by the customer
# * delayed previously: past delays at # the credit payment
# * critical/ other existing credit: critical credit accounts
# * no credits/ all paid: customer that never gets credit.
# * purpose: porpouse of the credit requested.
# * credit_amount: Amount of the credit requested
# * savings_status: Balance account of savings/ bond.
# * employment:How many years the customer has employed.
# * installment_commitment: Percentual that the customer cannot reach due to the income.
#
# --> When a customer takes a credit, the installment cannot ultrapass a percentual of customer income.
# * personal_status: if is divorced, married, etc.
# * other_parties: Another part involde on th credit, like guarantos ("fiador").
# * residence_since: How many year the customer has in the country.
# * property_magnitude: The good of the customer.
# * age: The age of the customer.
# * other_payment_plans: If the customer has another credit line and how the type (store, bank, etc).
# * housing:The housing customer type, could be own, for free or rent.
# * existing_credits: Number of existing credits at this bank.
# * job: This represents whats type of job the customer has. Could be skilled, unskilled resident, high qualif/self emp/mgmt and unemp/unskilled non res.
# * num_dependents: The number of depedents that live wth the customer.
# * own_telephone: If the customer has a telephone.
# * foreign_worker: If the customer is a foreign or not.
# * class: Our target. If the credit is goos or bad to the bank.

# %% [markdown]
# ### Importing Libraries to start EDA (Exploratory Data Analysis)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %% [markdown]
# ### Importing Dataset

# %%
# Importing the dataset
raw_data = pd.read_csv("credit_customers.csv",delimiter=',')
df = raw_data.copy()
df
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0       6.0  critical/other existing credit
# 1          0<=X<200      48.0                   existing paid
# 2       no checking      12.0  critical/other existing credit
# 3                <0      42.0                   existing paid
# 4                <0      24.0              delayed previously
# ..              ...       ...                             ...
# 995     no checking      12.0                   existing paid
# 996              <0      30.0                   existing paid
# 997     no checking      12.0                   existing paid
# 998              <0      45.0                   existing paid
# 999        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv         1169.0  no known savings         >=7
# 1               radio/tv         5951.0              <100      1<=X<4
# 2              education         2096.0              <100      4<=X<7
# 3    furniture/equipment         7882.0              <100      4<=X<7
# 4                new car         4870.0              <100      1<=X<4
# ..                   ...            ...               ...         ...
# 995  furniture/equipment         1736.0              <100      4<=X<7
# 996             used car         3857.0              <100      1<=X<4
# 997             radio/tv          804.0              <100         >=7
# 998             radio/tv         1845.0              <100      1<=X<4
# 999             used car         4576.0        100<=X<500  unemployed
#
#      installment_commitment     personal_status other_parties  ...  \
# 0                       4.0         male single          none  ...
# 1                       2.0  female div/dep/mar          none  ...
# 2                       2.0         male single          none  ...
# 3                       2.0         male single     guarantor  ...
# 4                       3.0         male single          none  ...
# ..                      ...                 ...           ...  ...
# 995                     3.0  female div/dep/mar          none  ...
# 996                     4.0        male div/sep          none  ...
# 997                     4.0         male single          none  ...
# 998                     4.0         male single          none  ...
# 999                     3.0         male single          none  ...
#
#      property_magnitude   age  other_payment_plans   housing existing_credits  \
# 0           real estate  67.0                 none       own              2.0
# 1           real estate  22.0                 none       own              1.0
# 2           real estate  49.0                 none       own              1.0
# 3        life insurance  45.0                 none  for free              1.0
# 4     no known property  53.0                 none  for free              2.0
# ..                  ...   ...                  ...       ...              ...
# 995         real estate  31.0                 none       own              1.0
# 996      life insurance  40.0                 none       own              1.0
# 997                 car  38.0                 none       own              1.0
# 998   no known property  23.0                 none  for free              1.0
# 999                 car  27.0                 none       own              1.0
#
#                            job num_dependents  own_telephone foreign_worker  \
# 0                      skilled            1.0            yes            yes
# 1                      skilled            1.0           none            yes
# 2           unskilled resident            2.0           none            yes
# 3                      skilled            2.0           none            yes
# 4                      skilled            2.0           none            yes
# ..                         ...            ...            ...            ...
# 995         unskilled resident            1.0           none            yes
# 996  high qualif/self emp/mgmt            1.0            yes            yes
# 997                    skilled            1.0           none            yes
# 998                    skilled            1.0            yes            yes
# 999                    skilled            1.0           none            yes
#
#     class
# 0    good
# 1     bad
# 2    good
# 3    good
# 4     bad
# ..    ...
# 995  good
# 996  good
# 997  good
# 998   bad
# 999  good
#
# [1000 rows x 21 columns]

# %% [markdown]
# ### Face 1: Executing Data cleaning

# %%
df.dtypes # All the values seems to be in the correct format
df.isnull().sum() # Checking for null values --> We do not have any null values in the dataset
df = df.drop_duplicates() # Dropping duplicates

    
    
# Cleaning the values from the job column for better understanding
df['job'] = df['job'].str.replace('unskilled resident','unskilled')
df['job'] = df['job'].str.replace('high qualif/self emp/mgmt','highqualif / selfemp')
df['job'] = df['job'].str.replace('unemp/unskilled non res','unemp/unsk/ nonres')

# %% [markdown]
# -----

# %% [markdown]
# ### Face 2: Data Visualization
#
# For this part of the project I decided to set questions / tasks  and answer them using plots.

# %%
# Getting the measures of central tendencies by duration
df_duration= df[['duration']].describe().round(2)
print(df_duration,'\n')

# Duration boxplot
df1 = df.groupby('duration')[['duration']].count()

plt.figure(figsize=(10,6))
sns.boxplot(data=df1,y=df1["duration"],width=0.125)
plt.ylabel('Duration in Months')
plt.xlabel('Loans')
plt.title('Credit duration per month boxplot', fontdict={'fontsize':'17'}, loc='center')
plt.show()

# Printing results
print('\n')
for i in range(1,len(df_duration['duration'])):
    print(f'The {df_duration.index[i]} loan duration is {df_duration.iloc[i,0]}')
# Out:
#        duration
# count   1000.00
# mean      20.90
# std       12.06
# min        4.00
# 25%       12.00
# 50%       18.00
# 75%       24.00
# max       72.00
# The mean loan duration is 20.9
# The std loan duration is 12.06
# The min loan duration is 4.0
# The 25% loan duration is 12.0
# The 50% loan duration is 18.0
# The 75% loan duration is 24.0
# The max loan duration is 72.0

# %% [markdown]
# #### Task / Question 2: Check the loan frequencies per purpose and their weight agaist to the total amount of loans

# %%
# Loan purpose frequency
df2 = df.groupby('purpose')[['credit_amount']].count().sort_values(by='credit_amount',ascending=False)

df2.plot(kind='barh',legend=False,figsize=(10,6))
plt.title('Frequency of loan purpose',fontdict={'fontsize':'17'}, loc='center')
plt.ylabel('Loan purpose')
plt.xlabel('q(x)')
plt.show()

# % Weight per purpose
df2 = df['purpose'].value_counts().to_frame()
df2['Total'] = 1000
df2.rename(columns={'count':'q(x)'},inplace= True)
df2['Weight'] = round((df2['q(x)']/df2['Total'])*100,2)


# Plot with labels and percentage
df2.plot(kind='pie',y='Weight', legend=None, figsize = (12,6))
plt.title('Pie chart regarding purpose weight on the dataset',fontdict={'fontsize':'14'},loc='center')
plt.show()

print('\n',df2,'\n')
for i in range(len(df2['Weight'])):
    print(f'The purpose {df2.index[i]} represent the {df2.iloc[i,2]}% from the total amount of loans')
# Out:
#                       q(x)  Total  Weight
# purpose
# radio/tv              280   1000    28.0
# new car               234   1000    23.4
# furniture/equipment   181   1000    18.1
# used car              103   1000    10.3
# business               97   1000     9.7
# education              50   1000     5.0
# repairs                22   1000     2.2
# domestic appliance     12   1000     1.2
# other                  12   1000     1.2
# retraining              9   1000     0.9
#
# The purpose radio/tv represent the 28.0% from the total amount of loans
# The purpose new car represent the 23.4% from the total amount of loans
# The purpose furniture/equipment represent the 18.1% from the total amount of loans
# The purpose used car represent the 10.3% from the total amount of loans
# The purpose business represent the 9.7% from the total amount of loans
# The purpose education represent the 5.0% from the total amount of loans
# The purpose repairs represent the 2.2% from the total amount of loans
# The purpose domestic appliance represent the 1.2% from the total amount of loans
# The purpose other represent the 1.2% from the total amount of loans
# The purpose retraining represent the 0.9% from the total amount of loans

# %% [markdown]
# -----

# %% [markdown]
# #### Task / Question 3: Check the measures of central tendencies regarding Credit Amount by Purpose

# %%
# Groupping by purpose and describing credit amount column
df3 = df.groupby('purpose')['credit_amount'].describe().T.round(2)
df3

# Line chart of mean credit amount requested per purpose
df3 = df3.T.reset_index()
purpose = df3['purpose']
mean_AC = df3['mean']

plt.figure(figsize=(18,6))
plt.plot(purpose,mean_AC,linewidth=3, marker='o')
plt.xlabel('Purpose')
plt.ylabel('Credit amount ($)')
plt.title('Mean amount credit per purpose',fontdict={'fontsize':'14'},loc='center')
plt.show()

df3

# Mean, min & max credit amount taken per purpose 
print('\n')
for i in range(0,len(df3.columns)):
    print(f'The mean credit amount taken for the purpose {df3.iloc[i,0]} is {df3.iloc[i,2]} american dollars.')
    print(f'The min credit amount taken for the purpose {df3.iloc[i,0]} is {df3.iloc[i,4]} american dollars.')
    print(f'The max credit amount taken for the purpose {df3.iloc[i,0]} is {df3.iloc[i,-1]} american dollars.')
    print('\n')

# Credit amount / purpose BoxPLot
plt.figure(figsize=(16,6))
sns.boxplot(data=df,y='credit_amount',width=0.5, orient='v', x='purpose')
plt.title('Credit amount / Purpose boxplot', fontdict={'fontsize':'17'})
plt.xlabel('Purpose')
plt.ylabel('Credit amount')
plt.show()

print('\n')

# Central measure variable of credit amount agaisnt purpose. Min, Max, Mean, Count, std, Q1, Q3
df3
# Out:
# The mean credit amount taken for the purpose business is 4158.04 american dollars.
# The min credit amount taken for the purpose business is 609.0 american dollars.
# The max credit amount taken for the purpose business is 15945.0 american dollars.
#
#
# The mean credit amount taken for the purpose domestic appliance is 1498.0 american dollars.
# The min credit amount taken for the purpose domestic appliance is 343.0 american dollars.
# The max credit amount taken for the purpose domestic appliance is 3990.0 american dollars.
#
#
# The mean credit amount taken for the purpose education is 3180.4 american dollars.
# The min credit amount taken for the purpose education is 392.0 american dollars.
# The max credit amount taken for the purpose education is 12612.0 american dollars.
#
#
# The mean credit amount taken for the purpose furniture/equipment is 3066.99 american dollars.
# The min credit amount taken for the purpose furniture/equipment is 428.0 american dollars.
# The max credit amount taken for the purpose furniture/equipment is 14179.0 american dollars.
#
#
# The mean credit amount taken for the purpose new car is 3063.03 american dollars.
# The min credit amount taken for the purpose new car is 250.0 american dollars.
# The max credit amount taken for the purpose new car is 14896.0 american dollars.
#
#
# The mean credit amount taken for the purpose other is 8209.33 american dollars.
# The min credit amount taken for the purpose other is 1164.0 american dollars.
# The max credit amount taken for the purpose other is 18424.0 american dollars.
#
#
# The mean credit amount taken for the purpose radio/tv is 2487.65 american dollars.
# The min credit amount taken for the purpose radio/tv is 338.0 american dollars.
# The max credit amount taken for the purpose radio/tv is 15653.0 american dollars.
#
#
# The mean credit amount taken for the purpose repairs is 2728.09 american dollars.
# The min credit amount taken for the purpose repairs is 454.0 american dollars.
# The max credit amount taken for the purpose repairs is 11998.0 american dollars.
#
#
# The mean credit amount taken for the purpose retraining is 1205.89 american dollars.
# The min credit amount taken for the purpose retraining is 339.0 american dollars.
# The max credit amount taken for the purpose retraining is 3447.0 american dollars.
#                purpose  count     mean      std     min      25%     50%  \
# 0             business   97.0  4158.04  3231.48   609.0  1908.00  3161.0
# 1   domestic appliance   12.0  1498.00  1012.51   343.0  1131.25  1249.0
# 2            education   50.0  3180.40  3017.94   392.0  1198.25  1884.5
# 3  furniture/equipment  181.0  3066.99  2034.15   428.0  1747.00  2578.0
# 4              new car  234.0  3063.03  2962.65   250.0  1241.50  1980.0
# 5                other   12.0  8209.33  6112.70  1164.0  2410.50  6948.0
# 6             radio/tv  280.0  2487.65  2073.69   338.0  1261.00  1890.0
# 7              repairs   22.0  2728.09  2627.49   454.0  1214.50  1749.0
# 8           retraining    9.0  1205.89   891.48   339.0   894.00   932.0
# 9             used car  103.0  5370.22  2890.97  1236.0  2917.00  4788.0
#
#         75%      max
# 0   5293.00  15945.0
# 1   1359.50   3990.0
# 2   4425.25  12612.0
# 3   3643.00  14179.0
# 4   3632.50  14896.0
# 5  12649.00  18424.0
# 6   3038.00  15653.0
# 7   3203.25  11998.0
# 8   1238.00   3447.0
# 9   7498.00  12976.0

# %% [markdown]
# -----

# %% [markdown]
# #### Task / Question 4: Check which group regarding employment status is the one that took more loans, and how much predominance they have on the dataset¶

# %%
# Groupping by employment and counting the empoyment
df5 = df.groupby('employment')['employment'].count().sort_values(ascending=False).to_frame()

# Getting the Weight (%) that each group represents on the dataset
df5['Weight'] = round((df5['employment']/ df5['employment'].sum())*100,2)
df5_str = df5.astype(str) # changing the values from int to str for printing

#Plotting a barplot regarding employment status
plt.figure(figsize=(12,6))
sns.barplot(x=df5.index,y=df5['employment'])
plt.title('Total Amount of loan took per employment year status',fontdict={'fontsize':'17'}, loc='center')
plt.xlabel('Employment')
plt.ylabel('Total amount of loans')
plt.show()

# Printing the 
for i in range(len(df5['employment'])):
    print(f'The {df5.index[i]} employment group took {df5.iloc[i,0]} loans, they represent the {df5.iloc[i,1]} % of the dataset.')

print('\n')
# Out:
# The 1<=X<4 employment group took 339 loans, they represent the 33.9 % of the dataset.
# The >=7 employment group took 253 loans, they represent the 25.3 % of the dataset.
# The 4<=X<7 employment group took 174 loans, they represent the 17.4 % of the dataset.
# The <1 employment group took 172 loans, they represent the 17.2 % of the dataset.
# The unemployed employment group took 62 loans, they represent the 6.2 % of the dataset.

# %% [markdown]
# #### Task / Question 4.1: Check the relationship between the Credit amount and Employment Status. Check the mean loan requested per employment status¶

# %%
# Groupping by employment and describing credit amount
df4 = df.groupby('employment')['credit_amount'].describe().round(2).T
df4 = df4.astype(str)
df4

# credit amount / employment Boxplot
plt.figure(figsize=(16,6))
sns.boxplot(data=df,y='credit_amount',width=0.4, orient='v', x='employment')
plt.title('Loan amount / Employment status in years boxplot',fontdict={'fontsize':'17'}, loc='center')
plt.xlabel('Purpose')
plt.ylabel('Credit amount')
plt.show()

# Printing the mean, min & max credit amount taken per employment status
print('\n')
for i in range(5):
    print('The mean credit amount take it for people with employment status '+ df4.columns[i] +' was : '+df4.iloc[1,i])
    print('The min credit amount take it for people with employment status '+ df4.columns[i] +' was : '+df4.iloc[3,i])
    print('The max credit amount take it for people with employment status '+ df4.columns[i] +' was : '+df4.iloc[-1,i])
    print('\n')

# Central measure variable of credit amount agaisnt employment status. Min, Max, Mean, Count, std, Q1, Q3
df4
# Out:
# The mean credit amount take it for people with employment status 1<=X<4 was : 3125.29
# The min credit amount take it for people with employment status 1<=X<4 was : 250.0
# The max credit amount take it for people with employment status 1<=X<4 was : 18424.0
#
#
# The mean credit amount take it for people with employment status 4<=X<7 was : 3601.7
# The min credit amount take it for people with employment status 4<=X<7 was : 385.0
# The max credit amount take it for people with employment status 4<=X<7 was : 15653.0
#
#
# The mean credit amount take it for people with employment status <1 was : 2952.45
# The min credit amount take it for people with employment status <1 was : 343.0
# The max credit amount take it for people with employment status <1 was : 15945.0
#
#
# The mean credit amount take it for people with employment status >=7 was : 3224.62
# The min credit amount take it for people with employment status >=7 was : 338.0
# The max credit amount take it for people with employment status >=7 was : 14896.0
#
#
# The mean credit amount take it for people with employment status unemployed was : 4216.76
# The min credit amount take it for people with employment status unemployed was : 433.0
# The max credit amount take it for people with employment status unemployed was : 15857.0
# employment   1<=X<4   4<=X<7       <1      >=7 unemployed
# count         339.0    174.0    172.0    253.0       62.0
# mean        3125.29   3601.7  2952.45  3224.62    4216.76
# std         2687.82   3025.7  2498.49  2809.15    3572.42
# min           250.0    385.0    343.0    338.0      433.0
# 25%          1377.5   1450.5   1335.5   1300.0     1357.5
# 50%          2235.0   2386.0   2139.0   2337.0     3044.0
# 75%          3884.0  4783.75  3572.25   3832.0     6429.5
# max         18424.0  15653.0  15945.0  14896.0    15857.0

# %% [markdown]
# -----

# %% [markdown]
# #### Question / Task 4.2: Check the purpose of each group of employment status and see what were they getting a loan for and see if there is a relation between them

# %%
# Counting values and indexing them by employment and purpose and reseting the index
df4 = df[['employment','purpose']].value_counts().sort_index()
df4 = df4.reset_index()
df4.head()

# Getting the unique values from the column employment
employment_categories = df4['employment'].unique()

# Plotting a countplot regarding job status and purpose for each group and printing the top purpose for each group.
for category in employment_categories:
    plt.figure(figsize=(10, 5))  
    
    subset = df4[df4['employment'] == category]
    subset.sort_values(by='count', ascending=False, inplace=True)
    
    print(sns.barplot(data=subset, y='purpose', x='count',orient='h'),
          f'\nThe top porpuse for status employment of {category} is "{subset.iloc[0,1]}" \n')
    
    plt.title(f'Purpose Counts for Employment: {category}',fontdict={'fontsize':'17'}, loc='center')
    plt.ylabel('Purpose')
    plt.xlabel('Count q(x)')
    plt.tight_layout() 
    plt.show()
# Out:
# Axes(0.125,0.11;0.775x0.77)
# The top porpuse for status employment of 1<=X<4 is "radio/tv"
# Axes(0.125,0.11;0.775x0.77)
# The top porpuse for status employment of 4<=X<7 is "radio/tv"
# Axes(0.125,0.11;0.775x0.77)
# The top porpuse for status employment of <1 is "radio/tv"
# Axes(0.125,0.11;0.775x0.77)
# The top porpuse for status employment of >=7 is "radio/tv"
# Axes(0.125,0.11;0.775x0.77)
# The top porpuse for status employment of unemployed is "new car"

# %% [markdown]
# ---

# %% [markdown]
# #### Task / Question 5: Check frequencies of loans regarding "Kind of job" variable and it's relationship between agaist loan duration

# %%
# Groupping by job and getting the frequencies for each kind of job the loan seekers have 
df6 = df.groupby('job')['duration'].count().sort_values(ascending=False).to_frame()
df6['Weight'] = round((df6['duration']/ df6['duration'].sum()*100),2)

# Plotting a barplot regarding frequencies of "Kind of job"
plt.figure(figsize=(12,5))
sns.barplot(x=df6.index,y=df6['duration'])
plt.title('Total amount of loans regarding Kind of job', fontdict={'fontsize':'17'}, loc='center')
plt.ylabel('q(x)')
plt.show()

print('\n')

# Printing the total requested loan for each group and their weight in the dataset
for i in range(len(df6['duration'])):
    print(f'The workers with a kind of job {df6.index[i]} requested {df6.iloc[i,0]} loans and they represent the {df6.iloc[i,1]}%')
df6
# Out:
# The workers with a kind of job skilled requested 630 loans and they represent the 63.0%
# The workers with a kind of job unskilled requested 200 loans and they represent the 20.0%
# The workers with a kind of job highqualif / selfemp requested 148 loans and they represent the 14.8%
# The workers with a kind of job unemp/unsk/ nonres requested 22 loans and they represent the 2.2%
#                       duration  Weight
# job
# skilled                    630    63.0
# unskilled                  200    20.0
# highqualif / selfemp       148    14.8
# unemp/unsk/ nonres          22     2.2

# %%
# Creating a dataframe that contains duration and job
df_skilled = df[['duration','job','class']]

# Plotting a box plot regarding job and loan duration
plt.figure(figsize=(16,6))
sns.boxplot(data=df_skilled,x='job',y='duration', width=0.4,hue='class')
plt.xlabel('Job')
plt.ylabel('Duration')
plt.title('Duration / Job boxplot',fontdict={'fontsize':'17'}, loc='center')
plt.show()

print('\n')
# Getting measures of central tendencies about duration agaisnt job and printing mean, min, max, Q1 & Q3
df_skilled = df_skilled.groupby('job')['duration'].describe().round(2)
df_skilled

for i in range(df_skilled.shape[1]):
    print(f'The {df_skilled.columns[i]} loan duration for {df_skilled.index[0]} was {df_skilled.iloc[0,i]}')
    print(f'The {df_skilled.columns[i]} loan duration for {df_skilled.index[1]} was {df_skilled.iloc[1,i]}')
    print(f'The {df_skilled.columns[i]} loan duration for {df_skilled.index[2]} was {df_skilled.iloc[2,i]}')
    print(f'The {df_skilled.columns[i]} loan duration for {df_skilled.index[3]} was {df_skilled.iloc[3,i]}\n')
# Out:
# The count loan duration for highqualif / selfemp was 148.0
# The count loan duration for skilled was 630.0
# The count loan duration for unemp/unsk/ nonres was 22.0
# The count loan duration for unskilled was 200.0
#
# The mean loan duration for highqualif / selfemp was 25.17
# The mean loan duration for skilled was 21.41
# The mean loan duration for unemp/unsk/ nonres was 17.36
# The mean loan duration for unskilled was 16.54
#
# The std loan duration for highqualif / selfemp was 13.41
# The std loan duration for skilled was 11.92
# The std loan duration for unemp/unsk/ nonres was 11.59
# The std loan duration for unskilled was 9.94
#
# The min loan duration for highqualif / selfemp was 6.0
# The min loan duration for skilled was 4.0
# The min loan duration for unemp/unsk/ nonres was 6.0
# The min loan duration for unskilled was 4.0
#
# The 25% loan duration for highqualif / selfemp was 14.75
# The 25% loan duration for skilled was 12.0
# The 25% loan duration for unemp/unsk/ nonres was 9.75
# The 25% loan duration for unskilled was 10.0
#
# The 50% loan duration for highqualif / selfemp was 24.0
# The 50% loan duration for skilled was 18.0
# The 50% loan duration for unemp/unsk/ nonres was 15.5
# The 50% loan duration for unskilled was 12.0
#
# The 75% loan duration for highqualif / selfemp was 36.0
# The 75% loan duration for skilled was 24.0
# The 75% loan duration for unemp/unsk/ nonres was 18.0
# The 75% loan duration for unskilled was 24.0
#
# The max loan duration for highqualif / selfemp was 60.0
# The max loan duration for skilled was 72.0
# The max loan duration for unemp/unsk/ nonres was 48.0
# The max loan duration for unskilled was 60.0

# %%
df_skilled = df
for i in np.unique(df['job']):
    df_skilled = df_skilled[['duration','job']]
    sub = df_skilled[df_skilled['job'] == i].value_counts()
    sub = sub.reset_index()
    print(sub.plot(kind='bar',x='duration',figsize=(20,5),rot=1,legend=None))
    
    plt.title(f'Job status = {i} | loan duration',fontdict={'fontsize':'15'})
    plt.xlabel('Duration')
    plt.ylabel('q(x)')
    plt.show()
# Out:
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ----

# %% [markdown]
# #### Task / Question 6: Check the ages of the loan seekers and their class frequencies

# %%
# Age / class Boxplot
plt.figure(figsize=(16,6))
sns.boxplot(data=df[['class','age']], x='class',y='age', width =0.2)
plt.xlabel('Class')
plt.ylabel('Age')
plt.title('Age / Class Boxplot',fontdict={'fontsize':'17'}, loc='center')
plt.show()

# Groupping by class, describing age and printing info 
df_class = df.groupby('class')['age'].describe().T.round(2)

for i in range(len(df_class['good'])):
    print(f'The {df_class.columns[0]} class {df_class.index[i]} age is {df_class.iloc[i,0]}')
    print(f'The {df_class.columns[1]} class {df_class.index[i]} age is {df_class.iloc[i,1]}')
    print('\n')
df_class
# Out:
# The bad class count age is 300.0
# The good class count age is 700.0
#
#
# The bad class mean age is 33.96
# The good class mean age is 36.22
#
#
# The bad class std age is 11.22
# The good class std age is 11.38
#
#
# The bad class min age is 19.0
# The good class min age is 19.0
#
#
# The bad class 25% age is 25.0
# The good class 25% age is 27.0
#
#
# The bad class 50% age is 31.0
# The good class 50% age is 34.0
#
#
# The bad class 75% age is 40.0
# The good class 75% age is 42.25
#
#
# The bad class max age is 74.0
# The good class max age is 75.0
# class     bad    good
# count  300.00  700.00
# mean    33.96   36.22
# std     11.22   11.38
# min     19.00   19.00
# 25%     25.00   27.00
# 50%     31.00   34.00
# 75%     40.00   42.25
# max     74.00   75.00

# %% [markdown]
# #### Question / Task 7: Check which group of worker took most loans and their variables¶

# %%
# groupping by personal status and counting them
df_personal_status = df['personal_status'].value_counts().sort_values(ascending=False).to_frame()
df_personal_status['Weight'] = round((df_personal_status['count']/df_personal_status['count'].sum())*100,2)
df_personal_status

df_personal_status.plot(kind='bar',y='count' , rot=0,figsize=(12,4), legend=None)
plt.title('Total amount of loans regarding personal status group', fontdict={'fontsize':'15'})
plt.xlabel('Personal status')
plt.ylabel('q(x)')
plt.show()


for i in range(len(df_personal_status['count'])):
        print(f'\nThe {df_personal_status.index[i]} group took {df_personal_status.iloc[i,0]} loans and they represent the {df_personal_status.iloc[i,1]}% of the total amount of loans.')
print('\n')
df_personal_status
# Out:
# The male single group took 548 loans and they represent the 54.8% of the total amount of loans.
#
# The female div/dep/mar group took 310 loans and they represent the 31.0% of the total amount of loans.
#
# The male mar/wid group took 92 loans and they represent the 9.2% of the total amount of loans.
#
# The male div/sep group took 50 loans and they represent the 5.0% of the total amount of loans.
#                     count  Weight
# personal_status
# male single           548    54.8
# female div/dep/mar    310    31.0
# male mar/wid           92     9.2
# male div/sep           50     5.0

# %% [markdown]
# ----

# %% [markdown]
# ### insights obtained from Face 2
#
# Measures of central tendencies regarding Loan duration
# * The mean loan duration is 20
# * The std loan duration is 12.06
# * The min loan duration is 4.0
# * The Q1 loan duration is 12.0
# * The median loan duration is 18
# * The Q3 loan duration is 24
# * The max loan duration is 72
#
# Loan Purposes
# * The Purpose Weight from the Total amount of loans
# * The purpose radio/tv represent the 28.0% from the total amount of loans
# * The purpose new car represent the 23.4% from the total amount of loans
# * The purpose furniture/equipment represent the 18.1% from the total amount of loans
# * The purpose used car represent the 10.3% from the total amount of loans
# * The purpose business represent the 9.7% from the total amount of loans
# * The purpose education represent the 5.0% from the total amount of loans
# * The purpose repairs represent the 2.2% from the total amount of loans
# * The purpose domestic appliance represent the 1.2% from the total amount of loans
# * The purpose other represent the 1.2% from the total amount of loans
# * The purpose retraining represent the 0.9% from the total amount of loans

# %%
plt.figure(figsize=(16,6))
sns.boxplot(data=df,y='credit_amount',width=0.5, orient='v', x='purpose')
plt.title('Credit amount / Purpose boxplot', fontdict={'fontsize':'17'})
plt.xlabel('Purpose')
plt.ylabel('Credit amount')
plt.show()

print('\n')
for i in range(0,len(df3.columns)):
    print(f'The mean credit amount taken for the purpose {df3.iloc[i,0]} is {df3.iloc[i,2]} american dollars.')

print('\nFor more information, please go to the Task 3')
# Out:
# The mean credit amount taken for the purpose business is 4158.04 american dollars.
# The mean credit amount taken for the purpose domestic appliance is 1498.0 american dollars.
# The mean credit amount taken for the purpose education is 3180.4 american dollars.
# The mean credit amount taken for the purpose furniture/equipment is 3066.99 american dollars.
# The mean credit amount taken for the purpose new car is 3063.03 american dollars.
# The mean credit amount taken for the purpose other is 8209.33 american dollars.
# The mean credit amount taken for the purpose radio/tv is 2487.65 american dollars.
# The mean credit amount taken for the purpose repairs is 2728.09 american dollars.
# The mean credit amount taken for the purpose retraining is 1205.89 american dollars.
#
# For more information, please go to the Task 3

# %% [markdown]
# ## Face 3: Machine Learning with Hyperparameter tuning

# %% [markdown]
# At this stage of the project, I will build several classification machine learning models to predict if a applicat is good or bad but firstly we will transform our categorical data into numerical and we will group them into:
# * ordinal (ranked),
# * nominal (unranked),
# * and target columns

# %%
# 1. Obtaining our string columns
categorical_columns = df.select_dtypes(include="string").columns
df[categorical_columns].head()
# Out:
#   checking_status                  credit_history              purpose  \
# 0              <0  critical/other existing credit             radio/tv
# 1        0<=X<200                   existing paid             radio/tv
# 2     no checking  critical/other existing credit            education
# 3              <0                   existing paid  furniture/equipment
# 4              <0              delayed previously              new car
#
#      savings_status employment     personal_status other_parties  \
# 0  no known savings        >=7         male single          none
# 1              <100     1<=X<4  female div/dep/mar          none
# 2              <100     4<=X<7         male single          none
# 3              <100     4<=X<7         male single     guarantor
# 4              <100     1<=X<4         male single          none
#
#   property_magnitude other_payment_plans   housing        job own_telephone  \
# 0        real estate                none       own    skilled           yes
# 1        real estate                none       own    skilled          none
# 2        real estate                none       own  unskilled          none
# 3     life insurance                none  for free    skilled          none
# 4  no known property                none  for free    skilled          none
#
#   foreign_worker class
# 0            yes  good
# 1            yes   bad
# 2            yes  good
# 3            yes  good
# 4            yes   bad

# %%
for i in categorical_columns:
    print(pd.DataFrame(df[i].value_counts()))
# Out:
#                  count
# checking_status
# no checking        394
# <0                 274
# 0<=X<200           269
# >=200               63
#                                 count
# credit_history
# existing paid                     530
# critical/other existing credit    293
# delayed previously                 88
# all paid                           49
# no credits/all paid                40
#                      count
# purpose
# radio/tv               280
# new car                234
# furniture/equipment    181
# used car               103
# business                97
# education               50
# repairs                 22
# domestic appliance      12
# other                   12
# retraining               9
#                   count
# savings_status
# <100                603
# no known savings    183
# 100<=X<500          103
# 500<=X<1000          63
# >=1000               48
#             count
# employment
# 1<=X<4        339
# >=7           253
# 4<=X<7        174
# <1            172
# unemployed     62
#                     count
# personal_status
# male single           548
# female div/dep/mar    310
# male mar/wid           92
# male div/sep           50
#                count
# other_parties
# none             907
# guarantor         52
# co applicant      41
#                     count
# property_magnitude
# car                   332
# real estate           282
# life insurance        232
# no known property     154
#                      count
# other_payment_plans
# none                   814
# bank                   139
# stores                  47
#           count
# housing
# own         713
# rent        179
# for free    108
#                       count
# job
# skilled                 630
# unskilled               200
# highqualif / selfemp    148
# unemp/unsk/ nonres       22
#                count
# own_telephone
# none             596
# yes              404
#                 count
# foreign_worker
# yes               963
# no                 37
#        count
# class
# good     700
# bad      300

# %%
# 1. Target Column (bad = 1, good = 0 for risk detection)
df['class'] = df['class'].map({'good': 0, 'bad': 1})

# 2. Ordinal / Ranked Features (True hierarchy)
ordinal_mappings = {
    'checking_status': {'no checking': 0, '<0': 1, '0<=X<200': 2, '>=200': 3},
    'savings_status': {'no known savings': 0, '<100': 1, '100<=X<500': 2, '500<=X<1000': 3, '>=1000': 4},
    'employment': {'unemployed': 0, '<1': 1, '1<=X<4': 2, '4<=X<7': 3, '>=7': 4},
    'job': {'unemp/unsk/ nonres': 0, 'unskilled': 1, 'skilled': 2, 'highqualif / selfemp': 3},
    'property_magnitude': {'no known property': 0, 'car': 1, 'life insurance': 2, 'real estate': 3}
}

for col, mapping in ordinal_mappings.items():
    df[col] = df[col].map(mapping)

# 3. Binary Features
df['foreign_worker'] = df['foreign_worker'].map({'no': 0, 'yes': 1})
df['own_telephone'] = df['own_telephone'].map({'none': 0, 'yes': 1})

# 4. Nominal / Unranked Features (One-Hot Encoded)
nominal_cols = [
    'credit_history',
    'purpose',
    'personal_status',
    'other_parties',
    'other_payment_plans',
    'housing'
]

df = pd.get_dummies(df, columns=nominal_cols, drop_first=True, dtype=int)

# 5. Transofmring float types columns into integers
df = df.astype("int")

# %%
df.isnull().sum()
# Out:
# checking_status                                  0
# duration                                         0
# credit_amount                                    0
# savings_status                                   0
# employment                                       0
# installment_commitment                           0
# residence_since                                  0
# property_magnitude                               0
# age                                              0
# existing_credits                                 0
# job                                              0
# num_dependents                                   0
# own_telephone                                    0
# foreign_worker                                   0
# class                                            0
# credit_history_critical/other existing credit    0
# credit_history_delayed previously                0
# credit_history_existing paid                     0
# credit_history_no credits/all paid               0
# purpose_domestic appliance                       0
# purpose_education                                0
# purpose_furniture/equipment                      0
# purpose_new car                                  0
# purpose_other                                    0
# purpose_radio/tv                                 0
# purpose_repairs                                  0
# purpose_retraining                               0
# purpose_used car                                 0
# personal_status_male div/sep                     0
# personal_status_male mar/wid                     0
# personal_status_male single                      0
# other_parties_guarantor                          0
# other_parties_none                               0
# other_payment_plans_none                         0
# other_payment_plans_stores                       0
# housing_own                                      0
# housing_rent                                     0
# dtype: int64

# %% [markdown]
# ------

# %% [markdown]
# #### Executing Train Test Split

# %%
# Importing libraries
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split

# Setting our target and independents columns
y= df["class"]
X = df.drop(columns= "class")


X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((700, 36), (300, 36), (700,), (300,))

# %% [markdown]
# ## Decision Tree Model - Credit Risk Project

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

dt_model = DecisionTreeClassifier(random_state = 42)

# the tunning parameters
param_grid_dt = {
    "criterion":["gini", "entropy"],
    "max_depth": [None,2,5,7,10,20],
    "min_samples_split":[2,3,4],
    "class_weight": [
        "balanced",
        {0: 1, 1: 1.5},  # Ponderación suave
        {0: 1, 1: 2.0},  # Error en 'Bad' cuesta el doble
        {0: 1, 1: 2.5},  # Error en 'Bad' cuesta 2.5 veces más
        {0: 1, 1: 3.0},  # Error en 'Bad' cuesta el triple
    ]
}

# Building the grid model
grid_dt = GridSearchCV(
    estimator = dt_model,
    param_grid = param_grid_dt,
    cv = 5,
    scoring="accuracy",
    n_jobs=-1,
    verbose=1)

# Training the model
grid_dt.fit(X_train,y_train)

best_dt = grid_dt.best_estimator_ # Getting the best estimators
DTC_pred = best_dt.predict(X_test) # Predicting y_test by using the best model

# Results
print("Best parameters: ", grid_dt.best_params_)
print("Best CV score: ", round(grid_dt.best_score_,2))
print(f"Accuracy :{round(accuracy_score(y_test, DTC_pred),2)}")


# Classification Report and Confusion Matrix
print("\nClassification Report:\n", classification_report(y_test, DTC_pred,  target_names = ["Good (0)", "Bad (1)"]))

cm = confusion_matrix(y_test, DTC_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix = cm,
    display_labels = ["Good (0)", "Bad (1)"]
)

disp.plot(cmap = "Blues", values_format = "d")
plt.grid(False)
plt.show()
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# Best parameters:  {'class_weight': {0: 1, 1: 2.5}, 'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 3}
# Best CV score:  0.71
# Accuracy :0.67
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     Good (0)       0.76      0.76      0.76       209
#      Bad (1)       0.45      0.45      0.45        91
#
#     accuracy                           0.67       300
#    macro avg       0.61      0.61      0.61       300
# weighted avg       0.67      0.67      0.67       300

# %% [markdown]
# ----

# %% [markdown]
# ## Knn Value Model - Credit Risk Project

# %%
# Importing libraries
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# Importing the classification model
knn_model = KNeighborsClassifier()


# Basic important parameter for Knn Model 

param_grid_knn = {
    'n_neighbors': list(range(1,21)),
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# Building the grid model
grid_knn = GridSearchCV(
    estimator = knn_model,
    param_grid = param_grid_knn,
    cv = 5,
    scoring="accuracy",
    n_jobs=-1,
    verbose=1)


# Training the model
grid_knn.fit(X_train,y_train)

best_knn = grid_knn.best_estimator_ # Getting the best estimators
Knn_pred = best_knn.predict(X_test) # Predicting y_test by using the best model

# Results
print("Best parameters: ", grid_knn.best_params_)
print("Best CV score: ", round(grid_knn.best_score_,2))
print(f"Accuracy :{round(accuracy_score(y_test, Knn_pred),2)}")
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best parameters:  {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'distance'}
# Best CV score:  0.74
# Accuracy :0.71

# %%
k_values = range(1, 21)

# Declaration and initialization of empty arrays
train_acc = []
test_acc = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)

    y_train_pred = knn.predict(X_train)
    train_acc.append(accuracy_score(y_train, y_train_pred))  # Store the values for training accuracy

    y_test_pred = knn.predict(X_test)
    test_acc.append(accuracy_score(y_test, y_test_pred))    # Store the values for testing accuracy

best_k = k_values[test_acc.index(max(test_acc))]
best_test_accuracy = max(test_acc)

# Plotting the K nei
plt.figure(figsize = (8, 5))
plt.plot(k_values, train_acc, label = "Training Accuracy")
plt.plot(k_values, test_acc, label = "Test Accuracy")

plt.xlabel("Number of Neighbors (k)")
plt.ylabel("Accuracy")
plt.title("kNN accuracy vs No. of Neighbors")

plt.xticks(k_values)

plt.legend()
plt.show()

print(f"Best k = {best_k}")
print(f"Best Test Accuracy = {best_test_accuracy:.3f}")
# Out:
# Best k = 15
# Best Test Accuracy = 0.713

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix

y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, X_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix = cm,
    display_labels = ["Bad", "Good"]
)

disp.plot(cmap = "Blues", values_format = "d")
plt.grid(False)
plt.show()

print("Classification Report:")
print(classification_report(y_test, y_pred, target_names = ["Bad", "Good"]))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          Bad       0.53      0.22      0.31        91
#         Good       0.73      0.91      0.81       209
#
#     accuracy                           0.70       300
#    macro avg       0.63      0.57      0.56       300
# weighted avg       0.67      0.70      0.66       300

# %% [markdown]
# ---

# %% [markdown]
# ## GaussianNB Model - Hyperparameter tuning

# %%
# Importing the libraries
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, ConfusionMatrixDisplay, confusion_matrix

# Importing the model
gnb = GaussianNB()

# Setting paramters
gnb_param = {"var_smoothing": np.logspace(0, -9, num=100)}

# Building the grid search
grid_gaussianNB = GridSearchCV(estimator=gnb, param_grid=gnb_param, cv=5, scoring='recall')

# Training the model
grid_gaussianNB.fit(X_train,y_train)

# Obtainig the best estimator and predicing y_test
best_gnb = grid_gaussianNB.best_estimator_ # Getting the best estimators
gnb_pred = grid_gaussianNB.predict(X_test) # Predicting y_test by using the best model

# Results
print("Best parameters: ", grid_gaussianNB.best_params_)
print("Best CV score: ", round(grid_gaussianNB.best_score_,2))
print(f"Accuracy :{round(accuracy_score(y_test, gnb_pred),2)}")

# Classification Report and Confusion Matrix
print("\nClassification Report:\n", classification_report(y_test, gnb_pred, target_names = ["Good (0)", "Bad (1)"]))

cm = confusion_matrix(y_test, gnb_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix = cm,
    display_labels = ["Good (1)", "Bad (1)"]
)

disp.plot(cmap = "Blues", values_format = "d")
plt.grid(False)
plt.show()
# Out:
# Best parameters:  {'var_smoothing': np.float64(1e-09)}
# Best CV score:  0.51
# Accuracy :0.71
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     Good (0)       0.79      0.79      0.79       209
#      Bad (1)       0.53      0.53      0.53        91
#
#     accuracy                           0.71       300
#    macro avg       0.66      0.66      0.66       300
# weighted avg       0.71      0.71      0.71       300

# %% [markdown]
# ----

# %% [markdown]
# ## AdaBoostClassifier Model - Hyperparameter tunning

# %%
# Importing the model
from sklearn.ensemble import AdaBoostClassifier

# creating the model
ada_model = AdaBoostClassifier(random_state = 42)

# Setting paramters
ada_param = {
    "n_estimators": [100,150,200,250],
    'learning_rate': [0.3, 0.5,0.8,1]}

# Building the GridSearch CV 
grid_adaboost = GridSearchCV(estimator=ada_model,
                               param_grid=ada_param,
                               cv=5,
                               scoring='recall')

# Training the model
grid_adaboost.fit(X_train,y_train)

# Obtainig the best estimator and predicing y_test
best_ada = grid_adaboost.best_estimator_ # Getting the best estimators
ada_pred = grid_adaboost.predict(X_test) # Predicting y_test by using the best model

# Results
print("Best parameters: ", grid_adaboost.best_params_)
print("Best CV score: ", round(grid_adaboost.best_score_,2))
print(f"Accuracy :{round(accuracy_score(y_test, ada_pred),2)}")

# Classification Report and Confusion Matrix
print("\nClassification Report:\n", classification_report(y_test, ada_pred, target_names = ["Good (0)", "Bad (1)"]))

cm = confusion_matrix(y_test, ada_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix = cm,
    display_labels = ["Good (0)", "Bad (1)"]
)

disp.plot(cmap = "Blues", values_format = "d")
plt.grid(False)
plt.show()
# Out:
# Best parameters:  {'learning_rate': 1, 'n_estimators': 250}
# Best CV score:  0.47
# Accuracy :0.72
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     Good (0)       0.76      0.88      0.81       209
#      Bad (1)       0.56      0.35      0.43        91
#
#     accuracy                           0.72       300
#    macro avg       0.66      0.62      0.62       300
# weighted avg       0.70      0.72      0.70       300

# %% [markdown]
# ------

# %% [markdown]
# ## Random Forest Classifier Model

# %%
# 1. Importing the libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# 2. Importing the model
rfc_model = RandomForestClassifier(random_state=42)

# 3. Setting grid parameter
rfd_param = {
    'n_estimators': [100, 200, 300],
    'max_features': ['sqrt', 'log2'],
    'bootstrap': [True, False]
}

# Building the GridSearch CV 
grid_rfd = GridSearchCV(estimator= rfc_model,
                               param_grid= rfd_param,
                               cv=5,
                               scoring='accuracy')

# Training the model
grid_rfd.fit(X_train,y_train)

# Obtainig the best estimator and predicing y_test
best_ada = grid_rfd.best_estimator_ # Getting the best estimators
rfd_pred = grid_rfd.predict(X_test) # Predicting y_test by using the best model

# Results
print("Best parameters: ", grid_rfd.best_params_)
print("Best CV score: ", round(grid_rfd.best_score_,2))
print(f"Accuracy :{round(accuracy_score(y_test, rfd_pred),2)}")

# Optional: more evaluation
print("\nClassification Report:\n", classification_report(y_test, rfd_pred))

cm = confusion_matrix(y_test, rfd_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix = cm,
    display_labels = ["Bad (0)", "Good (1)"]
)

disp.plot(cmap = "Blues", values_format = "d")
plt.grid(False)
plt.show()
# Out:
# Best parameters:  {'bootstrap': True, 'max_features': 'sqrt', 'n_estimators': 200}
# Best CV score:  0.76
# Accuracy :0.75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.94      0.84       209
#            1       0.71      0.32      0.44        91
#
#     accuracy                           0.75       300
#    macro avg       0.73      0.63      0.64       300
# weighted avg       0.74      0.75      0.72       300

# %% [markdown]
# ----

# %% [markdown]
# ### Comparing the models

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, RocCurveDisplay

# Confusion Matrix
cm_dtc = confusion_matrix(y_test, DTC_pred)
cm_gnb = confusion_matrix(y_test, gnb_pred)
cm_ada = confusion_matrix(y_test, ada_pred)
cm_rfd = confusion_matrix(y_test, rfd_pred)

# Display
disp_dtc = ConfusionMatrixDisplay(
    confusion_matrix = cm_dtc,
    display_labels = ["Good (0)", "Bad (1)"]
)

disp_gnb = ConfusionMatrixDisplay(
    confusion_matrix = cm_gnb,
    display_labels = ["Good (0)", "Bad (1)"]
)

disp_ada = ConfusionMatrixDisplay(
    confusion_matrix = cm_ada,
    display_labels = ["Good (0)", "Bad (1)"]
)

disp_rfd = ConfusionMatrixDisplay(
    confusion_matrix = cm_rfd,
    display_labels = ["Bad (0)", "Good (1)"]
)

# Plots
plt.figure(figsize=(10,10))
plt.subplot(2, 2, 1)
disp_dtc.plot(cmap="Blues", values_format="d", ax=plt.gca())
plt.grid(False)

plt.subplot(2, 2, 2)
disp_gnb.plot(cmap="Blues", values_format="d", ax=plt.gca())
plt.grid(False)

plt.subplot(2, 2, 3)
disp_ada.plot(cmap="Blues", values_format="d", ax=plt.gca())
plt.grid(False)

plt.subplot(2, 2, 4)
disp.plot(cmap = "Blues", values_format = "d", ax=plt.gca())
plt.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ## ANN Model (Artificial Neural network)

# %%
# 1. Importing libraries to build and execute ANN model
from keras.models import Sequential
from keras.layers import Dense, Dropout, Input
from sklearn.preprocessing import StandardScaler
import random
import tensorflow
tensorflow.random.set_seed(9)
np.random.seed(1)
random.seed(1)

# 2. Initiating Standard Scaler
sl = StandardScaler()

# 3. Scaling X
X_scaled = sl.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.3, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# 4. Initiating Sequential model
model_ann = Sequential()

# 6. Now we will add the layers and dropout into our model

model_ann.add(Dense(32, activation = "relu", input_dim = 20))
model_ann.add(Dropout(0.3))
model_ann.add(Dense(16, activation ="relu"))
model_ann.add(Dropout(0.2))
model_ann.add(Dense(1, activation = "sigmoid"))

# 7. Compiling the model 
model_ann.compile(
    optimizer="adam",           # the grand desciendent matters.
    loss="binary_crossentropy", # loss function for binary classification problems
    metrics = ["accuracy"])     # Metric to evaluate model performance
# Out:
# C:\Users\leona\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 8. Training the ANN model
model_ann.fit(X_train,y_train, epochs=50, batch_size=32)
# Check for Batchsize and validation data

# 9. Evaluating the results
print("\nTraining samples accuracy: ", round(model_ann.evaluate(X_train, y_train),2))
print("\nTesting samples accuracy: ", round(model_ann.evaluate(X_test, y_test),2))
print("--------------------------------------------------------------------")
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[302], line 2
#       1 # 8. Training the ANN model
# ----> 2 model_ann.fit(X_train,y_train, epochs=50, batch_size=32)
#       3 # Check for Batchsize and validation data
#       4
#       5 # 9. Evaluating the results
#       6 print("\nTraining samples accuracy: ", round(model_ann.evaluate(X_train, y_train),2))
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\layers\input_spec.py:228, in assert_input_compatibility(input_spec, inputs, layer_name)
#     223     for axis, value in spec.axes.items():
#     224         if value is not None and shape[axis] not in {
#     225             value,
#     226             None,
#     227         }:
# --> 228             raise ValueError(
#     229                 f"Input {input_index} with name '{spec.name}' of layer "
#     230                 f"'{layer_name}' is incompatible with the layer: "
#     231                 f"expected axis {axis} of input shape to have value "
#     232                 f"{value}, but received input with shape {shape}"
#     233             )
#     234 # Check shape.
#     235 if spec.shape is not None:
#
# ValueError: Exception encountered when calling Sequential.call().
#
# Input 0 with name 'None' of layer 'dense_3' is incompatible with the layer: expected axis -1 of input shape to have value 20, but received input with shape (None, 36)
#
# Arguments received by Sequential.call():
#   • inputs=tf.Tensor(shape=(None, 36), dtype=float32)
#   • training=True
#   • mask=None
#   • kwargs=<class 'inspect._empty'>

# %%
# 1. Executing prediction
ann_pred = model_ann.predict(X_test).flatten()

# 2. Transforming into binary classes
ann_pred_binary = (ann_pred > 0.5).astype(int)

# 3. Generar e Imprimir el Classification Report
print("\n--- CLASSIFICATION REPORT ---\n")
print(classification_report(y_test, ann_pred_binary, target_names=["Bad (0)", "Good (1)"]))

# 4. Generar la Matriz de Confusión
c_matrix = confusion_matrix(y_test, ann_pred_binary)

plt.figure(figsize=(6, 4))
ax = sns.heatmap(
    c_matrix,
    annot=True,
    fmt="d",  # 'd' para mostrar números enteros sin notación científica
    cmap="Blues",
    cbar=False,
    xticklabels=["Bad (0)", "Good (1)"],
    yticklabels=["Bad (0)", "Good (1)"],
)

ax.set_xlabel("Predicción")
ax.set_ylabel("Valor Real")
ax.set_title("Matriz de Confusión")
plt.show()

# %% [markdown]
# ### ANN Model (Artificial Neural network) - Hyparparameter Tunning

# %%
# 1. Importing libraries to build and execute ANN model
from keras.models import Sequential
from keras.layers import Dense, Dropout, Input
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV

import random
import tensorflow

tensorflow.random.set_seed(9)
np.random.seed(1)
random.seed(1)

# 2. Initiating Standard Scaler
sl = StandardScaler()


# 1. Define build function with arguments matching the grid
def build_model(hidden_units=16, learning_rate=0.01):
    model = Sequential([
        Input(shape=(X_train.shape[1],)),
        Dense(hidden_units, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(
        optimizer=optimizer,
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

# 2. Use KerasClassifier 
nn_model = KerasClassifier(
    model=build_model,
    verbose=0
)

# 3. Define the parameter grid
ann_grid = {
    "model__hidden_units": [16, 32],
    "model__learning_rate": [0.1, 0.01, 0.001],
    "batch_size": [16, 32],
    "epochs": [50, 100, 150]
}

# 4. Initialize and fit GridSearchCV
grid_nn = GridSearchCV(
    estimator=nn_model,
    param_grid=ann_grid,
    cv=3,
    scoring="accuracy",
    n_jobs=1
)

grid_nn.fit(X_train, y_train)

# 5. Evaluate best model
best_model = grid_nn.best_estimator_
y_pred = best_model.predict(X_test)

print("\nBest Parameters:", grid_nn.best_params_)
print(f"Best CV Score: {round(grid_nn.best_score_ * 100, 2)}%")
# Out:
# WARNING:tensorflow:5 out of the last 24 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000018A367C9620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000018A3516EFC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# Best Parameters: {'batch_size': 32, 'epochs': 100, 'model__hidden_units': 32, 'model__learning_rate': 0.001}
# Best CV Score: 70.86%

# %%
print(f"Accuracy: {round(accuracy_score(y_test,y_pred)*100,2)}%")
# Out:
# Accuracy: 73.0%

# %% [markdown]
# ----

# %% [markdown]
# ## Result Summary from all our Classification models
# Models executed:
# * Decision Tree Model
# * Knn Value Model
# * GaussianNB Model
# * AdaBoostClassifier Model
# * Random Forest Model

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, RocCurveDisplay

cm_gnb = confusion_matrix(y_test, gnb_pred)
cm_ada = confusion_matrix(y_test, ada_pred)


disp_gnb = ConfusionMatrixDisplay(
    confusion_matrix = cm_gnb,
    display_labels = ["Bad", "Good"]
)


disp_ada = ConfusionMatrixDisplay(
    confusion_matrix = cm_ada,
    display_labels = ["Bad", "Good"]
)

plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
disp_gnb.plot(cmap="Blues", values_format="d", ax=plt.gca())
plt.grid(False)

plt.subplot(1, 2, 2)
disp_ada.plot(cmap="Blues", values_format="d", ax=plt.gca())
plt.grid(False)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score

# %%
# Decision Tree
print("Decision Tree Model Accuracy = ", round(accuracy_score(y_test, DTC_pred),2),"\n")
print("\nClassification Report:\n", classification_report(y_test, DTC_pred))
print("------------------------------------------------------------")

# Knn Value
print("Knn Value Model")
print(f"Best k = {best_k}")
print(f"Best Test Accuracy = {best_test_accuracy:.3f}")
print(classification_report(y_test, y_pred, target_names = ["Bad", "Good"]))
print("------------------------------------------------------------")

# Gaussian Naive Bayes / GaussianNB Model
print("\nGaussian Naive Bayes - Without StandardScaler")
print("Accuracy: ", round(accuracy_score(y_test, gnb_pred),4))
print("ROC AUC: ", round(roc_auc_score(y_test, gnb_preda),4))
print(classification_report(y_test, gnb_pred,target_names = ["Bad", "Good"]))
print("------------------------------------------------------------")

# AdaBoost Classifier model
print("\nAdaBoost Classifier Model")
print("Accuracy: ", round(accuracy_score(y_test, ada_pred),4))
print("ROC AUC: ", round(roc_auc_score(y_test, ada_proba),4))
print(classification_report(y_test, ada_pred,target_names = ["Bad", "Good"]))
print("------------------------------------------------------------")

# Random Forest Classifier Model
print("\nRandom Forest Classifier Model")
print(f"Accuracy: {accuracy_score(y_test, RFC_pred):.4f}")
print("Reporte de clasificación:")
print(classification_report(y_test, RFC_pred,target_names = ["Bad", "Good"]))
# Out:
# Decision Tree Model Accuracy =  0.69
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.89      0.80       209
#            1       0.49      0.24      0.32        91
#
#     accuracy                           0.69       300
#    macro avg       0.61      0.57      0.56       300
# weighted avg       0.66      0.69      0.66       300
#
# ------------------------------------------------------------
# Knn Value Model
# Best k = 20
# Best Test Accuracy = 0.697
#               precision    recall  f1-score   support
#
#          Bad       0.70      0.97      0.82       209
#         Good       0.50      0.07      0.12        91
#
#     accuracy                           0.70       300
#    macro avg       0.60      0.52      0.47       300
# weighted avg       0.64      0.70      0.60       300
#
# ------------------------------------------------------------
#
# Gaussian Naive Bayes - Without StandardScaler
# Accuracy:  0.7367
# ROC AUC:  0.7508
#               precision    recall  f1-score   support
#
#          Bad       0.77      0.89      0.82       209
#         Good       0.60      0.40      0.48        91
#
#     accuracy                           0.74       300
#    macro avg       0.69      0.64      0.65       300
# weighted avg       0.72      0.74      0.72       300
#
# ------------------------------------------------------------
#
# AdaBoost Classifier Model
# Accuracy:  0.73
# ROC AUC:  0.7896
#               precision    recall  f1-score   support
#
#          Bad       0.76      0.89      0.82       209
#         Good       0.59      0.36      0.45        91
#
#     accuracy                           0.73       300
#    macro avg       0.68      0.63      0.64       300
# weighted avg       0.71      0.73      0.71       300
#
# ------------------------------------------------------------
#
# Random Forest Classifier Model
# Accuracy: 0.7500
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#          Bad       0.77      0.92      0.84       209
#         Good       0.66      0.36      0.47        91
#
#     accuracy                           0.75       300
#    macro avg       0.71      0.64      0.65       300
# weighted avg       0.74      0.75      0.72       300

# %% [markdown]
# ## Summary of results
# ![image.png](attachment:c6a7909c-4284-4401-9604-5dd4b9cfe9d6.png)

# %% [markdown]
# ![image.png](attachment:e64ea027-5ef6-4d1f-8dc7-01efbb64b7d1.png)

# %% [markdown]
# ----

# %% [markdown]
# ### Importing Machine Learning Model

# %%
# pip install fastapi uvicorn joblib pandas scikit-learn tensorflow

# %%
model
# Out:
# <Sequential name=sequential, built=True>

# %%
selected_model = model
import joblib

# Guardar el modelo y el preprocesador
#joblib.dump(selected_model, "modelo_credito.pkl")
selected_model.save("credit_model.keras")

# Guardar el escalador
joblib.dump(sl, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
import joblib
import numpy as np
from fastapi import FastAPI
from keras.models import load_model
from pydantic import BaseModel

# 1. Starting FastAPI
app = FastAPI(
    title="API - Testing Credit Risk",
    description="The purpose of this API is to predict if a customer is reliable for taking loans",
)

# 2. Importing the model and scaler model
model = load_model("credit_model.keras")
scaler = joblib.load("scaler.pkl")


# 3. Definir el esquema de datos de entrada (las 20 características)
# 3. Define the data schema for the entry (the 20 features)
class CustomerInput(BaseModel):
    features: list[float]  # Lista con los 20 valores numéricos del cliente


# 4. Ruta principal de prueba
@app.get("/")
def home():
    return {
        "Message": "Credit Risk API is active. Go to /docs for testing."
    }


# 5. Ruta de predicción
@app.post("/predict")
def prediction(cliente: CustomerInput):
    # Validar que ingresen exactamente 20 features
    if len(cliente.features) != 20:
        return {
            "error": f"20 characteristics were expected, but only received {len(cliente.features)}."
        }

    # 
    datos_cliente = np.array(cliente.features).reshape(1, -1)
    datos_escalados = scaler.transform(datos_cliente)

    # Predict
    prediccion_prob = model.predict(datos_escalados)[0][0]

    # Classification
    good = float(prediccion_prob) > 0.5
    resultado = "Good (Low risk)" if good else "Bad (High risk)"

    return {
        "Result": resultado,
        "Good_probabilities": round(float(prediccion_prob), 4),
        "Approve_loan": good,
    }

# %% [markdown]
# ----
